# %% [markdown]
# # Tutorial: Running TCAV with TabPFN
# This short notebook demonstrates how to invoke the new pipeline and inspect the most relevant outputs.

# %%
# %load_ext autoreload
# %autoreload 2
from src.pipelines import TCAVPipelineConfig, run_full_tcav_pipeline

# %% [markdown]
# ## Configure the run

# %%
cfg = TCAVPipelineConfig(
    data_path="free_light_chain_mortality.csv",
    n_clusters=6,
    kpca_components=48,
    show_plots=True,
    embedding_max_samples=5000,
)
cfg

# %% [markdown]
# ## Run the pipeline

# %%
outputs = run_full_tcav_pipeline(cfg)
outputs.inference.metrics

# %% [markdown]
# ## Inspect TCAV summary

# %%
outputs.tcav_frame.head()
